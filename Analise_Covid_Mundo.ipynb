# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Analise de Numeros de Casos confirmados no Mundo
#
# #Dados = "https://github.com/CSSEGISandData/COVID-19"

# %%
casos = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
casos.head(40)
# Out:
#                   Province/State          Country/Region  ...   4/30/21    5/1/21
# 0                            NaN             Afghanistan  ...     59745     59939
# 1                            NaN                 Albania  ...    131085    131185
# 2                            NaN                 Algeria  ...    122108    122311
# 3                            NaN                 Andorra  ...     13232     13232
# 4                            NaN                  Angola  ...     26652     26815
# 5                            NaN     Antigua and Barbuda  ...      1232      1232
# 6                            NaN               Argentina  ...   2977363   2993865
# 7                            NaN                 Armenia  ...    216064    216596
# 8   Australian Capital Territory               Australia  ...       124       124
# 9                New South Wales               Australia  ...      5481      5484
# ...

# %%
casos.tail()
# Out:
#     Province/State      Country/Region        Lat  ...  4/29/21  4/30/21  5/1/21
# 270            NaN             Vietnam  14.058324  ...     2910     2928    2942
# 271            NaN  West Bank and Gaza  31.952200  ...   295601   296462  296462
# 272            NaN               Yemen  15.552727  ...     6294     6317    6325
# 273            NaN              Zambia -13.133897  ...    91533    91586   91670
# 274            NaN            Zimbabwe -19.015438  ...    38235    38257   38260
#
# [5 rows x 470 columns]

# %%
# Vamos verificar o tamanho do dataset, depois iremos usar essa função para 
# manter atualizado os dados, pois aumenta a cada dia as culunas

casos.shape
# Out:
# (275, 470)

# %%
# Vamos utilizar a função "iloc" para acessar os dados por linhas e coulnas
# Utilizando o numpy vamos somar as colunas
casos = np.sum(casos.iloc[ : , 4 : casos.shape[1]])

# Vamos transformar as datas em index
casos.index = pd.DatetimeIndex(casos.index)

#Vamos mostrar as ultimas linhas do dataset
casos.tail(10)
# Out:
# 2021-04-22    144742575
# 2021-04-23    145640414
# 2021-04-24    146461651
# 2021-04-25    147189618
# 2021-04-26    147872402
# 2021-04-27    148716872
# 2021-04-28    149622864
# 2021-04-29    150520466
# 2021-04-30    151399480
# 2021-05-01    152196159
# dtype: int64

# %%
# Vamos plotar os dados para analise
casos.plot()

# %% [markdown]
# # Verificando os obitos

# %%
# Analisando os dados sobre obitos abrindo dataset
mortes = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
#Analisando as ultimas linhas 
mortes.tail()
# Out:
#     Province/State      Country/Region        Lat  ...  4/29/21  4/30/21  5/1/21
# 270            NaN             Vietnam  14.058324  ...       35       35      35
# 271            NaN  West Bank and Gaza  31.952200  ...     3231     3249    3249
# 272            NaN               Yemen  15.552727  ...     1222     1226    1229
# 273            NaN              Zambia -13.133897  ...     1250     1251    1251
# 274            NaN            Zimbabwe -19.015438  ...     1567     1567    1568
#
# [5 rows x 470 columns]

# %%
#Analisando o tamanho do dataset
mortes.shape
# Out:
# (275, 470)

# %%
# Vamos utilizar a função "iloc" para acessar os dados por linhas e coulnas
# Utilizando o numpy vamos somar as colunas
mortes = np.sum(mortes.iloc[ : , 4 : mortes.shape[1]])

# Vamos transformar as datas em index
mortes.index = pd.DatetimeIndex(casos.index)

#Vamos mostrar as ultimas linhas do dataset
mortes.tail(10)
# Out:
# 2021-04-22    3072028
# 2021-04-23    3086217
# 2021-04-24    3099533
# 2021-04-25    3109313
# 2021-04-26    3120469
# 2021-04-27    3134956
# 2021-04-28    3150675
# 2021-04-29    3165665
# 2021-04-30    3180238
# 2021-05-01    3192583
# dtype: int64

# %%
mortes.plot()

# %%
# Vamos cruzar as informações sobre os dois dataFrame para uma analise mais profunda

mortalidade = (mortes/casos)*100

# %%
mortalidade.plot()

# %% [markdown]
# # Analisaremos os dados dos recuperados

# %%
#Analisando os recuperados
recuperados = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
#Tamanho do dataset
recuperados.shape
# Out:
# (260, 470)

# %%
# Vamos utilizar a função "iloc" para acessar os dados por linhas e coulnas
# Utilizando o numpy vamos somar as colunas
recuperados = np.sum(recuperados.iloc[ : , 4 : recuperados.shape[1]])

# Vamos transformar as datas em index
recuperados.index = pd.DatetimeIndex(recuperados.index)

#Vamos mostrar as ultimas linhas do dataset
recuperados.tail(10)
# Out:
# 2021-04-22    83128167
# 2021-04-23    83763801
# 2021-04-24    84340966
# 2021-04-25    84878104
# 2021-04-26    85565470
# 2021-04-27    86246374
# 2021-04-28    86843039
# 2021-04-29    87550355
# 2021-04-30    88236951
# 2021-05-01    88919401
# dtype: int64

# %%
#Plotando os dataset
recuperados.plot()

# %% [markdown]
# # Analisaremos os ativos para termos uma real visão dos casos curados

# %%
#Analisndo os ativos
ativos = casos - (recuperados+mortes)

# %%
#Ultimas linhas do dataset
ativos.tail()
# Out:
# 2021-04-27    59335542
# 2021-04-28    59629150
# 2021-04-29    59804446
# 2021-04-30    59982291
# 2021-05-01    60084175
# dtype: int64

# %%
#Plotando as informações
ativos.plot()

# %%
# Vamos usar a função "concat" e juntar todos os dataframes construidos em um só

df = pd.concat([casos, ativos, recuperados, mortes], axis=1)

# Colocar os nomes das colunas
df.columns = (['casos', 'ativos', 'recuperados',' mortes'])

# Vamos analisar as ultimas linhas do dataset
df.tail()
# Out:
#                 casos    ativos  recuperados   mortes
# 2021-04-27  148716872  59335542     86246374  3134956
# 2021-04-28  149622864  59629150     86843039  3150675
# 2021-04-29  150520466  59804446     87550355  3165665
# 2021-04-30  151399480  59982291     88236951  3180238
# 2021-05-01  152196159  60084175     88919401  3192583

# %%
# Plotar as informações geradas

df.plot()
